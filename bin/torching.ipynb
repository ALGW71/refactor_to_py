# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# 1.13.1
# False

# %%
# Run the read data script made earlier to load your data
# %run read_data.py

plt.rcParams['figure.figsize'] = [20, 10]

# %%
# what do we got?
print(type(data))

print(type(data[1]))
# Out:
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>

# %%
data[1].shape
# Out:
# (43, 17)

# %%
data[0].iloc[0:10, [0,1,4,6,-3,-4,-5,-1]]
# some thing is wrong with the data
# Out:
#    Clone ID  Clone count                        Clonal sequence quality(s)  \
# 0         0         5894              SSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSS
# 1         1         3066              SSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSS
# 2         2         2480        SSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSS
# 3         4         1327  SSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSS
# 4         6          297  SSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSS
# 5         8           49           SSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSS
# 6         9           31           SSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSS
# 7        10           25                 SSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSS
# 8        11           23        SSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSS
# 9        12           22           SSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSS
#
#    All D hits  chain epitope     AA. Seq. CDR3  length
# 0         NaN  alpha     dpf      CAFPGSARQLTF      12
# ...

# %%
## load the sequences into tensors
# must convert each sequence to a one hot encoded matrix
# have a dimension for chain
# a dimension for epitope
# a dimension for donor
# each must be numeric

# %%
a = []
for i in range(50):
    a = a + data[i]["length"].tolist()

# show the first 10 elements
a[0:10]

len(a)
# Out:
# [12, 12, 14, 16, 16, 13, 13, 11, 14, 13]
# 1099

# %%
# cannot convert immediately to a tensor as it will have one dimension
# we need 1099

b = torch.empty(1099,1)

for i in range(1099):
    b[i] = a[i]
    
b[1:10]
b.shape
# Out:
# tensor([[12.],
#         [14.],
#         [16.],
#         [16.],
#         [13.],
#         [13.],
#         [11.],
#         [14.],
#         [13.]])
# torch.Size([1099, 1])
