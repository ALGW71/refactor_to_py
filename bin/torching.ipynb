# %%
# Run the read data script made earlier to load your data

plt.rcParams['figure.figsize'] = [15, 10]

# %run read_data.py

# %%
# what do we got?
type(data)
type(data[1])

data[1].shape

data[1].iloc[0:10, [0,4,6,-3,-4,-5]]
# Out:
#    Clone count                             All V hits         All J hits  \
# 0        14133                     TRBV7-2*00(1433.6)  TRBJ2-1*00(193.8)
# 1         7854                        TRBV2*00(893.6)  TRBJ1-5*00(250.2)
# 2         3641                     TRBV7-8*00(1178.7)  TRBJ2-7*00(214.5)
# 3         2152                     TRBV7-8*00(1206.8)  TRBJ1-1*00(215.1)
# 4          642                    TRBV20-1*00(1657.5)  TRBJ2-3*00(222.8)
# 5          641                     TRBV7-2*00(1309.2)  TRBJ2-1*00(199.6)
# 6          541  TRBV6-2*00(1160.5),TRBV6-3*00(1157.1)  TRBJ2-7*00(208.8)
# 7          174                     TRBV7-2*00(1446.1)  TRBJ2-2*00(274.3)
# 8           69                     TRBV5-1*00(1664.9)  TRBJ2-5*00(198.7)
# 9           58   TRBV4-2*00(1041.7),TRBV4-3*00(915.7)  TRBJ1-5*00(249.5)
#
#   chain epitope           AA. Seq. CDR3
# 0  beta     dpf         CASSLVLAGGRKQFF
# 1  beta     dpf         CASSSRTTSNQPQHF
# 2  beta     dpf         CASSLRFGGSHEQYF
# ...
